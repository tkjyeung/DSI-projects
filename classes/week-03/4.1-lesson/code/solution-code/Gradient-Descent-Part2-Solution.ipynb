# %% [markdown]
# # Gradients Descent - Part 2

# %%
% matplotlib inline
import random

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
from sklearn import datasets, linear_model
import math

# %% [markdown]
# #### Generate some data
#
# Using function $y = 4 + 3 x_1 + 10 x_2$

# %%
real_thetas = [4, 3, 10] 
n_thetas = len(real_thetas)

# %%
def generate_data(real_thetas, size, vmin, vmax, noise_var):
    x0=np.ones(size)
    X = np.array([x0] + \
                 [np.random.uniform(vmin, vmax, size=size)
                  for _ in range(len(real_thetas)-1)])

    # add noise
    y = np.dot(real_thetas, X) + np.random.normal(0.0, noise_var, size=size) 
    return X, y

# %%
X, y = generate_data(real_thetas=real_thetas, size=1000, vmin=0, vmax=1, noise_var=1.0)

# %% [markdown]
# ### Define the cost function

# %%
def cost_function(thetas, X, y):
    return np.mean(np.power(np.dot(X.T, thetas) - y, 2))/2.0

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent_step(thetas, alpha, X, y, momentum=1.0, momentum_factor=0.9):
    n = float(len(X))
    
    # Make sure X has theta[0]
    pred = np.dot(X.T, thetas) 
    loss = pred - y
    gradient =  np.dot(X, loss.T) / n 
    # gradient =  np.sum(X * loss) / n 
    delta = momentum_factor*momentum + alpha * gradient
    thetas = thetas - delta
    
    return thetas, delta

# %%
def print_thetas_cost(thetas, cost, delta_cost = None):
    print "C:{0:8.4f}\tXs:".format(cost),
    for t in thetas:
        print "{0:8.4f}".format(t),

    if delta_cost and delta_cost > 0:
        print "↓"
    else:
        print "↑"

# %%
def gradient_descent(X, y, n_thetas, alpha=0.0005, max_steps=1000, 
                     momentum=0.0, momentum_factor=0.9, verbose=1):

    thetas = np.ones(n_thetas)

    costs = [cost_function(thetas, X, y)]
    if verbose > 0:
        print_thetas_cost(thetas, costs[-1])
    
    for i in range(max_steps):
        thetas, momentum = gradient_descent_step(thetas, alpha, X, y, momentum)
        cost = cost_function(thetas, X, y)
        costs.append(cost)
        if len(costs) > 1:
            delta_cost = costs[-2] - costs[-1]

            if verbose > 0:
                print_thetas_cost(thetas, cost, delta_cost)
            
            if abs(delta_cost) < 0.0000001:
                print 
                print "Converged @", i
                break
                
    return thetas, costs[-1]

# %%
thetas, cost = gradient_descent(X, y, verbose=0)
print "Found this:"
print_thetas_cost(thetas, cost)
print "Real is:"
print_thetas_cost(real_thetas, 0.0)
# Out:
# Converged @ 144
# Found this:
# C:  0.4755	Xs:   9.9713   4.1502   8.9524 -40.0674  23.0712 ↑
# Real is:
# C:  0.0000	Xs:  10.0000   4.0000   9.0000 -40.0000  23.0000 ↑

# %% [markdown]
# ### Exercise: Test another data set generated from by: $y = 10 + 4x_1 + 9x_2 - 40x_3 + 23x_4$

# %%
# code here

real_thetas = [10, 4, 9, -40, 23] 
n_thetas = len(real_thetas)

X, y = generate_data(real_thetas=real_thetas, size=1000, vmin=0, vmax=1, noise_var=1.0)

# %%
thetas, cost = gradient_descent(X, y, n_thetas=n_thetas, verbose=1)
print "Found this:"
print_thetas_cost(thetas, cost)
print "Real is:"
print_thetas_cost(real_thetas, 0.0)
# Out:
# C:116.3142	Xs:   1.0000   1.0000   1.0000   1.0000   1.0000 ↑
# C:108.7416	Xs:   1.5839   1.3248   1.3692   0.9202   1.4848 ↓
# C: 98.6267	Xs:   2.5793   1.8806   2.0119   0.7144   2.3441 ↓
# C: 90.9277	Xs:   3.7517   2.5404   2.8007   0.3042   3.4351 ↓
# C: 87.0813	Xs:   4.8578   3.1724   3.6038  -0.3951   4.6110 ↓
# C: 84.7950	Xs:   5.6958   3.6671   4.3109  -1.4484   5.7477 ↓
# C: 80.6083	Xs:   6.1415   3.9568   4.8515  -2.8837   6.7630 ↓
# C: 72.8150	Xs:   6.1661   4.0243   5.2039  -4.6828   7.6258 ↓
# C: 62.5317	Xs:   5.8314   3.9018   5.3929  -6.7841   8.3539 ↓
# C: 52.4785	Xs:   5.2684   3.6580   5.4790  -9.0930   9.0029 ↓
# C: 44.7985	Xs:   4.6431   3.3808   5.5410 -11.4996   9.6477 ↓
# C: 39.6939	Xs:   4.1189   3.1568   5.6569 -13.8972  10.3628 ↓
# C: 35.7239	Xs:   3.8236   3.0532   5.8867 -16.1993  11.2049 ↓
# C: 31.2301	Xs:   3.8262   3.1063   6.2613 -18.3509  12.2008 ↓
# C: 25.6329	Xs:   4.1289   3.3164   6.7780 -20.3328  13.3427 ↓
# C: 19.6747	Xs:   4.6730   3.6515   7.4035 -22.1582  14.5917 ↓
# C: 14.6340	Xs:   5.3566   4.0564   8.0830 -23.8640  15.8872 ↓
# C: 11.2843	Xs:   6.0599   4.4665   8.7529 -25.4981  17.1597 ↓
# C:  9.4098	Xs:   6.6709   4.8213   9.3543 -27.1062  18.3450 ↓
# C:  8.1304	Xs:   7.1073   5.0766   9.8436 -28.7206  19.3952 ↓
# C:  6.6453	Xs:   7.3304   5.2114  10.1999 -30.3536  20.2865 ↓
# C:  4.7728	Xs:   7.3485   5.2300  10.4265 -31.9952  21.0205 ↓
# C:  2.9316	Xs:   7.2102   5.1583  10.5476 -33.6166  21.6208 ↓
# C:  1.6846	Xs:   6.9904   5.0365  10.6012 -35.1769  22.1258 ↓
# C:  1.2639	Xs:   6.7727   4.9096  10.6299 -36.6324  22.5789 ↓
# C:  1.4291	Xs:   6.6310   4.8171  10.6717 -37.9450  23.0189 ↑
# C:  1.7011	Xs:   6.6156   4.7862  10.7527 -39.0896  23.4727 ↑
# C:  1.7285	Xs:   6.7453   4.8272  10.8834 -40.0578  23.9509 ↑
# C:  1.4938	Xs:   7.0066   4.9332  11.0578 -40.8585  24.4474 ↓
# C:  1.2388	Xs:   7.3595   5.0831  11.2567 -41.5140  24.9427 ↓
# C:  1.2178	Xs:   7.7487   5.2475  11.4531 -42.0555  25.4091 ↓
# C:  1.4915	Xs:   8.1160   5.3956  11.6187 -42.5159  25.8178 ↑
# C:  1.9052	Xs:   8.4124   5.5017  11.7301 -42.9239  26.1453 ↑
# C:  2.2314	Xs:   8.6077   5.5498  11.7733 -43.2990  26.3778 ↑
# C:  2.3421	Xs:   8.6940   5.5362  11.7458 -43.6500  26.5138 ↑
# C:  2.2774	Xs:   8.6858   5.4690  11.6567 -43.9746  26.5634 ↓
# C:  2.1799	Xs:   8.6142   5.3654  11.5232 -44.2621  26.5460 ↓
# C:  2.1687	Xs:   8.5195   5.2472  11.3674 -44.4975  26.4853 ↓
# C:  2.2556	Xs:   8.4416   5.1362  11.2111 -44.6658  26.4053 ↑
# C:  2.3576	Xs:   8.4121   5.0499  11.0720 -44.7564  26.3255 ↑
# C:  2.3766	Xs:   8.4489   4.9981  10.9606 -44.7653  26.2579 ↑
# C:  2.2765	Xs:   8.5537   4.9820  10.8789 -44.6967  26.2060 ↓
# C:  2.1001	Xs:   8.7132   4.9951  10.8218 -44.5620  26.1656 ↓
# C:  1.9256	Xs:   8.9038   5.0248  10.7783 -44.3780  26.1264 ↓
# C:  1.8053	Xs:   9.0970   5.0563  10.7351 -44.1633  26.0758 ↓
# C:  1.7350	Xs:   9.2660   5.0754  10.6795 -43.9359  26.0018 ↓
# C:  1.6704	Xs:   9.3906   5.0718  10.6024 -43.7097  25.8961 ↓
# C:  1.5698	Xs:   9.4614   5.0405  10.4999 -43.4935  25.7554 ↓
# C:  1.4259	Xs:   9.4800   4.9826  10.3734 -43.2901  25.5826 ↓
# C:  1.2668	Xs:   9.4578   4.9044  10.2297 -43.0969  25.3856 ↓
# C:  1.1301	Xs:   9.4130   4.8159  10.0786 -42.9080  25.1754 ↓
# C:  1.0346	Xs:   9.3657   4.7281   9.9309 -42.7160  24.9642 ↓
# C:  0.9713	Xs:   9.3343   4.6508   9.7964 -42.5143  24.7630 ↓
# C:  0.9155	Xs:   9.3312   4.5909   9.6819 -42.2989  24.5797 ↓
# C:  0.8487	Xs:   9.3616   4.5512   9.5903 -42.0692  24.4180 ↓
# C:  0.7705	Xs:   9.4228   4.5304   9.5205 -41.8285  24.2774 ↓
# C:  0.6959	Xs:   9.5055   4.5236   9.4679 -41.5829  24.1539 ↓
# C:  0.6409	Xs:   9.5967   4.5238   9.4261 -41.3404  24.0413 ↓
# C:  0.6102	Xs:   9.6825   4.5235   9.3880 -41.1091  23.9327 ↓
# C:  0.5954	Xs:   9.7510   4.5166   9.3475 -40.8959  23.8224 ↓
# C:  0.5835	Xs:   9.7949   4.4989   9.3009 -40.7054  23.7069 ↓
# C:  0.5660	Xs:   9.8119   4.4695   9.2469 -40.5390  23.5853 ↓
# C:  0.5445	Xs:   9.8055   4.4299   9.1872 -40.3957  23.4596 ↓
# C:  0.5264	Xs:   9.7830   4.3841   9.1253 -40.2719  23.3337 ↓
# C:  0.5182	Xs:   9.7541   4.3373   9.0660 -40.1630  23.2129 ↓
# C:  0.5202	Xs:   9.7285   4.2946   9.0140 -40.0640  23.1022 ↑
# C:  0.5269	Xs:   9.7141   4.2601   8.9730 -39.9709  23.0057 ↑
# C:  0.5320	Xs:   9.7154   4.2363   8.9450 -39.8812  22.9257 ↑
# C:  0.5325	Xs:   9.7330   4.2233   8.9301 -39.7944  22.8622 ↑
# C:  0.5300	Xs:   9.7640   4.2194   8.9264 -39.7115  22.8135 ↓
# C:  0.5284	Xs:   9.8027   4.2217   8.9309 -39.6350  22.7764 ↓
# C:  0.5305	Xs:   9.8424   4.2264   8.9398 -39.5678  22.7468 ↑
# C:  0.5357	Xs:   9.8767   4.2299   8.9494 -39.5126  22.7212 ↑
# C:  0.5412	Xs:   9.9005   4.2295   8.9570 -39.4713  22.6966 ↑
# C:  0.5442	Xs:   9.9115   4.2238   8.9610 -39.4447  22.6712 ↑
# C:  0.5441	Xs:   9.9100   4.2128   8.9612 -39.4318  22.6449 ↓
# C:  0.5422	Xs:   9.8986   4.1980   8.9588 -39.4308  22.6187 ↓
# C:  0.5406	Xs:   9.8816   4.1815   8.9556 -39.4390  22.5944 ↓
# C:  0.5404	Xs:   9.8640   4.1658   8.9539 -39.4532  22.5744 ↓
# C:  0.5412	Xs:   9.8501   4.1532   8.9556 -39.4706  22.5605 ↑
# C:  0.5417	Xs:   9.8431   4.1454   8.9621 -39.4891  22.5540 ↑
# C:  0.5406	Xs:   9.8443   4.1429   8.9739 -39.5073  22.5552 ↓
# C:  0.5381	Xs:   9.8531   4.1453   8.9903 -39.5252  22.5636 ↓
# C:  0.5351	Xs:   9.8674   4.1515   9.0103 -39.5432  22.5775 ↓
# C:  0.5325	Xs:   9.8841   4.1596   9.0319 -39.5623  22.5950 ↓
# C:  0.5309	Xs:   9.8999   4.1679   9.0532 -39.5838  22.6141 ↓
# C:  0.5298	Xs:   9.9118   4.1746   9.0728 -39.6086  22.6329 ↓
# C:  0.5285	Xs:   9.9179   4.1788   9.0894 -39.6374  22.6502 ↓
# C:  0.5267	Xs:   9.9178   4.1801   9.1027 -39.6700  22.6653 ↓
# C:  0.5245	Xs:   9.9121   4.1788   9.1130 -39.7056  22.6784 ↓
# C:  0.5223	Xs:   9.9027   4.1758   9.1209 -39.7432  22.6902 ↓
# C:  0.5207	Xs:   9.8917   4.1722   9.1277 -39.7811  22.7017 ↓
# C:  0.5196	Xs:   9.8816   4.1694   9.1344 -39.8181  22.7139 ↓
# C:  0.5189	Xs:   9.8742   4.1682   9.1419 -39.8529  22.7278 ↓
# C:  0.5182	Xs:   9.8708   4.1692   9.1508 -39.8847  22.7436 ↓
# C:  0.5173	Xs:   9.8714   4.1726   9.1612 -39.9133  22.7614 ↓
# C:  0.5163	Xs:   9.8754   4.1778   9.1726 -39.9389  22.7808 ↓
# C:  0.5155	Xs:   9.8815   4.1843   9.1844 -39.9620  22.8008 ↓
# C:  0.5150	Xs:   9.8881   4.1910   9.1957 -39.9833  22.8206 ↓
# C:  0.5147	Xs:   9.8936   4.1971   9.2057 -40.0036  22.8391 ↓
# C:  0.5147	Xs:   9.8967   4.2019   9.2139 -40.0235  22.8558 ↓
# C:  0.5146	Xs:   9.8969   4.2051   9.2199 -40.0431  22.8702 ↓
# C:  0.5144	Xs:   9.8942   4.2068   9.2237 -40.0625  22.8823 ↓
# C:  0.5141	Xs:   9.8892   4.2071   9.2258 -40.0814  22.8924 ↓
# C:  0.5140	Xs:   9.8829   4.2066   9.2265 -40.0992  22.9010 ↓
# C:  0.5140	Xs:   9.8764   4.2060   9.2266 -40.1155  22.9087 ↓
# C:  0.5141	Xs:   9.8710   4.2058   9.2267 -40.1297  22.9161 ↑
# C:  0.5142	Xs:   9.8672   4.2065   9.2270 -40.1415  22.9235 ↑
# C:  0.5142	Xs:   9.8656   4.2081   9.2280 -40.1507  22.9313 ↑
# C:  0.5142	Xs:   9.8658   4.2107   9.2295 -40.1576  22.9392 ↓
# C:  0.5142	Xs:   9.8676   4.2139   9.2313 -40.1624  22.9472 ↓
# C:  0.5142	Xs:   9.8700   4.2174   9.2331 -40.1656  22.9548 ↓
# C:  0.5142	Xs:   9.8723   4.2207   9.2344 -40.1676  22.9615 ↑
# C:  0.5143	Xs:   9.8738   4.2235   9.2351 -40.1690  22.9672 ↑
# C:  0.5143	Xs:   9.8740   4.2255   9.2348 -40.1700  22.9715 ↑
# C:  0.5143	Xs:   9.8728   4.2266   9.2336 -40.1708  22.9744 ↑
# C:  0.5143	Xs:   9.8703   4.2269   9.2315 -40.1714  22.9761 ↓
# C:  0.5143	Xs:   9.8670   4.2266   9.2288 -40.1717  22.9768 ↓
# C:  0.5142	Xs:   9.8633   4.2261   9.2258 -40.1715  22.9768 ↓
# C:  0.5142	Xs:   9.8599   4.2256   9.2228 -40.1705  22.9764 ↓
# C:  0.5142	Xs:   9.8571   4.2253   9.2201 -40.1687  22.9760 ↓
# C:  0.5142	Xs:   9.8554   4.2255   9.2178 -40.1660  22.9758 ↓
# C:  0.5142	Xs:   9.8547   4.2262   9.2161 -40.1623  22.9757 ↓
# C:  0.5141	Xs:   9.8549   4.2273   9.2147 -40.1579  22.9758 ↓
# C:  0.5141	Xs:   9.8556   4.2286   9.2137 -40.1530  22.9759 ↓
# C:  0.5141	Xs:   9.8566   4.2300   9.2127 -40.1478  22.9759 ↓
# C:  0.5140	Xs:   9.8573   4.2311   9.2117 -40.1426  22.9756 ↓
# C:  0.5140	Xs:   9.8575   4.2319   9.2105 -40.1376  22.9748 ↓
# C:  0.5140	Xs:   9.8571   4.2324   9.2091 -40.1329  22.9735 ↓
# C:  0.5140	Xs:   9.8560   4.2324   9.2073 -40.1286  22.9718 ↓
# C:  0.5139	Xs:   9.8544   4.2320   9.2054 -40.1245  22.9697 ↓
# C:  0.5139	Xs:   9.8525   4.2315   9.2034 -40.1207  22.9674 ↓
# C:  0.5139	Xs:   9.8506   4.2309   9.2014 -40.1170  22.9650 ↓
# C:  0.5139	Xs:   9.8489   4.2304   9.1997 -40.1134  22.9627 ↓
# C:  0.5139	Xs:   9.8477   4.2302   9.1984 -40.1097  22.9606 ↓
# C:  0.5139	Xs:   9.8470   4.2301   9.1973 -40.1059  22.9589 ↓
# C:  0.5138	Xs:   9.8468   4.2303   9.1967 -40.1021  22.9574 ↓
# C:  0.5138	Xs:   9.8470   4.2307   9.1963 -40.0982  22.9561 ↓
# C:  0.5138	Xs:   9.8474   4.2312   9.1961 -40.0946  22.9550 ↓
# C:  0.5138	Xs:   9.8478   4.2316   9.1960 -40.0911  22.9540 ↓
# C:  0.5138	Xs:   9.8480   4.2319   9.1959 -40.0879  22.9529 ↓
# C:  0.5138	Xs:   9.8480   4.2321   9.1957 -40.0852  22.9517 ↑
# C:  0.5138	Xs:   9.8476   4.2321   9.1955 -40.0828  22.9505 ↓
# C:  0.5138	Xs:   9.8470   4.2319   9.1952 -40.0808  22.9491 ↓
# C:  0.5138	Xs:   9.8461   4.2316   9.1948 -40.0791  22.9478 ↓
# C:  0.5138	Xs:   9.8452   4.2312   9.1945 -40.0777  22.9464 ↓
# C:  0.5138	Xs:   9.8443   4.2308   9.1942 -40.0765  22.9452 ↑
# C:  0.5138	Xs:   9.8436   4.2306   9.1941 -40.0754  22.9442 ↑
# C:  0.5138	Xs:   9.8432   4.2304   9.1942 -40.0743  22.9433 ↑
# C:  0.5138	Xs:   9.8430   4.2304   9.1945 -40.0734  22.9427 ↑
# C:  0.5138	Xs:   9.8430   4.2306   9.1949 -40.0724  22.9423 ↓
# C:  0.5138	Xs:   9.8432   4.2307   9.1954 -40.0716  22.9420 ↓
# C:  0.5138	Xs:   9.8435   4.2309   9.1959 -40.0709  22.9419 ↑
#
# Converged @ 151
# Found this:
# C:  0.5138	Xs:   9.8435   4.2309   9.1959 -40.0709  22.9419 ↑
# Real is:
# C:  0.0000	Xs:  10.0000   4.0000   9.0000 -40.0000  23.0000 ↑
