# %% [markdown]
# # Data Workflow Lab 1
#
# Clean and summarize Project 3 data.
#
# ### Learning Objectives
#
# * Practice text cleaning techniques
# * Practice datatype conversion
# * Practice filling in missing values with either 0 or the average in the column
# * Practice categorical data techniques
# * Transform data into usable quantities

# %%
% matplotlib inline
import datetime
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# u'/vagrant/DSI_JY/DSI-projects/classes/week-03/3.3-lab/code/starter-code'

# %%
# Load the data
df = pd.read_csv("../../../../../projects/project-03/Iowa_Liquor_sales_sample_10pct.csv")
print df.columns
df.head()
# Out:
# Index([u'Date', u'Store Number', u'City', u'Zip Code', u'County Number',
#        u'County', u'Category', u'Category Name', u'Vendor Number',
#        u'Item Number', u'Item Description', u'Bottle Volume (ml)',
#        u'State Bottle Cost', u'State Bottle Retail', u'Bottles Sold',
#        u'Sale (Dollars)', u'Volume Sold (Liters)', u'Volume Sold (Gallons)'],
#       dtype='object')
#          Date  Store Number         City Zip Code  County Number      County  \
# 0  11/04/2015          3717       SUMNER    50674            9.0      Bremer
# 1  03/02/2016          2614    DAVENPORT    52807           82.0       Scott
# 2  02/11/2016          2106  CEDAR FALLS    50613            7.0  Black Hawk
# 3  02/03/2016          2501         AMES    50010           85.0       Story
# 4  08/18/2015          3654      BELMOND    50421           99.0      Wright
#
#     Category              Category Name  Vendor Number  Item Number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#             Item Description  Bottle Volume (ml) State Bottle Cost  \
# 0  Mr. Boston Apricot Brandy                 750             $4.50
# 1                    Tin Cup                 750            $13.75
# 2                   Jim Beam                1000            $12.59
# 3    1800 Ultimate Margarita                1750             $9.50
# 4         Five O'clock Vodka                1750             $7.20
#
#   State Bottle Retail  Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 0               $6.75            12         $81.00                   9.0
# 1              $20.63             2         $41.26                   1.5
# 2              $18.89            24        $453.36                  24.0
# 3              $14.25             6         $85.50                  10.5
# 4              $10.80            12        $129.60                  21.0
#
#    Volume Sold (Gallons)
# 0                   2.38
# 1                   0.40
# 2                   6.34
# 3                   2.77
# 4                   5.55

# %% [markdown]
# ## Clean the data
#
# Let's practice our data cleaning skills on the Project 3 dataset. If you don't remember how to do any of these tasks, look back at your work from the previous weeks or search the internet. There are many blog articles and Stack Overflow posts that cover these topics.
#
# You'll want to complete at least the following tasks:
# * Remove redundant columns
# * Remove "$" prices from characters and convert values to floats.
# * Convert dates to pandas datetime objects
# * Convert category floats to integers
# * Drop or fill in bad values

# %%
# Remove redundant columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270955 entries, 0 to 270954
# Data columns (total 18 columns):
# Date                     270955 non-null object
# Store Number             270955 non-null int64
# City                     270955 non-null object
# Zip Code                 270955 non-null object
# County Number            269878 non-null float64
# County                   269878 non-null object
# Category                 270887 non-null float64
# Category Name            270323 non-null object
# Vendor Number            270955 non-null int64
# Item Number              270955 non-null int64
# Item Description         270955 non-null object
# Bottle Volume (ml)       270955 non-null int64
# State Bottle Cost        270955 non-null object
# State Bottle Retail      270955 non-null object
# Bottles Sold             270955 non-null int64
# Sale (Dollars)           270955 non-null object
# Volume Sold (Liters)     270955 non-null float64
# Volume Sold (Gallons)    270955 non-null float64
# dtypes: float64(4), int64(5), object(9)
# memory usage: 37.2+ MB

# %%
df['Item Description'].value_counts().count()
# Out:
# 2173

# %%
df.drop('Volume Sold (Gallons)',axis=1, inplace = True)

# %%
df.isnull().sum()
# Out:
# Date                       0
# Store Number               0
# City                       0
# Zip Code                   0
# County Number           1077
# County                  1077
# Category                  68
# Category Name            632
# Vendor Number              0
# Item Number                0
# Item Description           0
# Bottle Volume (ml)         0
# State Bottle Cost          0
# State Bottle Retail        0
# Bottles Sold               0
# Sale (Dollars)             0
# Volume Sold (Liters)       0
# dtype: int64

# %%
df['State Bottle Cost'] = df['State Bottle Cost'].str.replace('$','').astype(float)

# %%
df['State Bottle Retail'] = df['State Bottle Retail'].str.replace('$','').astype(float)

# %%
df['Sale (Dollars)'] = df['Sale (Dollars)'].str.replace('$','').astype(float)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
pd.pivot_table(df, columns = 'Store Number')[['County Number']].value_counts()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-86-ef35e7d12253> in <module>()
# ----> 1 df.groupby(by = 'Store Number')[['County Number']].value_counts()
#
# /home/vagrant/.anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __getattr__(self, attr)
#     496
#     497         raise AttributeError("%r object has no attribute %r" %
# --> 498                              (type(self).__name__, attr))
#     499
#     500     plot = property(GroupByPlot)
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'value_counts'

# %%
df[df['County Number'].isnull()].sample(10)
# Out:
#              Date  Store Number          City Zip Code  County Number County  \
# 199501 2016-03-22          5210      CLARINDA    51632            NaN    NaN
# 249514 2016-03-09          2637     DAVENPORT    52804            NaN    NaN
# 78668  2016-01-25          3591        ACKLEY    50601            NaN    NaN
# 228451 2016-02-01          4222     EVANSDALE    50707            NaN    NaN
# 230854 2016-02-23          5210      CLARINDA    51632            NaN    NaN
# 155982 2016-03-15          3632       DUBUQUE    52003            NaN    NaN
# 27055  2016-02-16          5230  CEDAR RAPIDS    52402            NaN    NaN
# 169878 2015-09-08          4247       BELMOND    50421            NaN    NaN
# 95655  2016-03-15          3632       DUBUQUE    52003            NaN    NaN
# 163578 2016-01-20          4308    CORALVILLE    52241            NaN    NaN
#
#          Category       Category Name  Vendor Number  Item Number  \
# 199501  1012200.0     SCOTCH WHISKIES             55         8827
# 249514  1062300.0        FLAVORED RUM            370        43536
# 78668   1081015.0   IMPORTED AMARETTO            130        64136
# 228451  1062300.0        FLAVORED RUM             35        43136
# 230854  1011100.0    BLENDED WHISKIES            260        25608
# 155982  1081390.0   IMPORTED SCHNAPPS            260        69946
# 27055   1011300.0  TENNESSEE WHISKIES             85        26821
# 169878  1011300.0  TENNESSEE WHISKIES             85        86670
# 95655   1022100.0             TEQUILA            395        89215
# 163578  1031080.0      VODKA 80 PROOF            297        35914
#
#                                 Item Description  Bottle Volume (ml)  \
# 199501                                  Lauder's                1000
# 249514         Malibu Pineapple Upside Down Cake                 750
# 78668                         Disaronno Amaretto                 750
# 228451                             Bacardi Limon                 750
# 230854               Seagrams 7 Crown Bl Whiskey                1750
# 155982  Rumple Minze Peppermint Schnapps Liqueur                 750
# 27055         Jack Daniels Old #7 Black Lbl Mini                 500
# 169878             Jack Daniel's Tennessee Honey                 750
# 95655   Jose Cuervo Tradicional Reposado Tequila                 750
# 163578                        Five O'clock Vodka                 375
#
#         State Bottle Cost  State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 199501               6.14                 9.21             3           27.63
# 249514               7.49                11.24            12          134.88
# 78668               13.86                20.79             3           62.37
# 228451               8.26                12.39             4           49.56
# 230854              11.96                17.94             6          107.64
# 155982              13.00                19.50            12          234.00
# 27055                9.06                13.59             2           27.18
# 169878              15.07                22.61            12          271.32
# 95655               14.90                22.35            12          268.20
# 163578               1.93                 2.90            24           69.60
#
#         Volume Sold (Liters)
# 199501                  3.00
# 249514                  9.00
# 78668                   2.25
# 228451                  3.00
# 230854                 10.50
# 155982                  9.00
# 27055                   1.00
# 169878                  9.00
# 95655                   9.00
# 163578                  9.00

# %%
# Remove $ from certain columns

# %%
df[df['County Number'].isnull()]['Store Number'].value_counts()
# Out:
# 4247    153
# 3820     83
# 5210     80
# 5230     65
# 2637     64
# 2460     64
# 5220     61
# 5236     49
# 3632     40
# 5222     33
# 4307     31
# 3682     28
# 5227     27
# 4222     23
# 2353     23
# 4203     23
# 2650     23
# 5224     20
# 4214     14
# 3591     14
# 5225     14
# 4308     13
# 4169     13
# 5226     13
# 5214     12
# 3747     11
# 2152     10
# 2238      9
# 5247      7
# 5240      7
# 4006      6
# 5217      6
# 5237      6
# 5229      5
# 5232      4
# 5233      4
# 5208      4
# 3826      4
# 5234      3
# 5223      3
# 5216      3
# 5218      2
# Name: Store Number, dtype: int64

# %%
df[df['Store Number']==4247]
# Out:
#              Date  Store Number     City Zip Code  County Number  County  \
# 964    2015-05-19          4247  BELMOND    50421            NaN     NaN
# 2871   2015-09-22          4247  BELMOND    50421            NaN     NaN
# 4448   2015-03-03          4247  BELMOND    50421            NaN     NaN
# 7834   2015-03-17          4247  BELMOND    50421            NaN     NaN
# 9790   2015-10-20          4247  BELMOND    50421            NaN     NaN
# 12422  2015-03-17          4247  BELMOND    50421            NaN     NaN
# 13112  2015-08-04          4247  BELMOND    50421            NaN     NaN
# 13686  2016-02-23          4247  BELMOND    50421            NaN     NaN
# 14529  2015-07-21          4247  BELMOND    50421            NaN     NaN
# 16512  2015-03-17          4247  BELMOND    50421            NaN     NaN
# 19443  2015-12-04          4247  BELMOND    50421           99.0  Wright
# 23084  2015-12-29          4247  BELMOND    50421           99.0  Wright
# 23110  2015-05-05          4247  BELMOND    50421            NaN     NaN
# 24082  2015-07-14          4247  BELMOND    50421            NaN     NaN
# 26604  2016-03-22          4247  BELMOND    50421            NaN     NaN
# 27256  2015-03-10          4247  BELMOND    50421            NaN     NaN
# 27547  2015-11-03          4247  BELMOND    50421            NaN     NaN
# 27758  2016-01-05          4247  BELMOND    50421            NaN     NaN
# 29819  2015-02-17          4247  BELMOND    50421            NaN     NaN
# 30141  2015-02-17          4247  BELMOND    50421            NaN     NaN
# 31851  2015-09-15          4247  BELMOND    50421            NaN     NaN
# 31930  2015-10-20          4247  BELMOND    50421            NaN     NaN
# 32099  2015-08-11          4247  BELMOND    50421            NaN     NaN
# 32540  2015-02-17          4247  BELMOND    50421            NaN     NaN
# 34547  2015-05-12          4247  BELMOND    50421            NaN     NaN
# 36506  2015-10-20          4247  BELMOND    50421            NaN     NaN
# 37416  2015-07-14          4247  BELMOND    50421            NaN     NaN
# 39498  2015-06-23          4247  BELMOND    50421            NaN     NaN
# 39499  2016-02-02          4247  BELMOND    50421            NaN     NaN
# 41806  2016-03-08          4247  BELMOND    50421            NaN     NaN
# ...           ...           ...      ...      ...            ...     ...
# 218031 2016-02-02          4247  BELMOND    50421            NaN     NaN
# 220009 2016-02-09          4247  BELMOND    50421            NaN     NaN
# 220722 2015-12-01          4247  BELMOND    50421           99.0  Wright
# 221210 2016-02-09          4247  BELMOND    50421            NaN     NaN
# 221749 2016-02-02          4247  BELMOND    50421            NaN     NaN
# 225517 2016-02-16          4247  BELMOND    50421            NaN     NaN
# 226288 2015-03-03          4247  BELMOND    50421            NaN     NaN
# 227326 2015-11-17          4247  BELMOND    50421            NaN     NaN
# 228545 2015-01-06          4247  BELMOND    50421            NaN     NaN
# 230169 2015-06-23          4247  BELMOND    50421            NaN     NaN
# 231428 2015-02-17          4247  BELMOND    50421            NaN     NaN
# 232148 2015-10-20          4247  BELMOND    50421            NaN     NaN
# 233261 2015-12-21          4247  BELMOND    50421           99.0  Wright
# 234443 2015-05-19          4247  BELMOND    50421            NaN     NaN
# 235688 2015-09-29          4247  BELMOND    50421            NaN     NaN
# 237344 2015-02-17          4247  BELMOND    50421            NaN     NaN
# 239262 2015-12-01          4247  BELMOND    50421           99.0  Wright
# 239729 2015-08-11          4247  BELMOND    50421            NaN     NaN
# 239926 2016-02-16          4247  BELMOND    50421            NaN     NaN
# 243489 2015-02-17          4247  BELMOND    50421            NaN     NaN
# 251269 2016-03-15          4247  BELMOND    50421            NaN     NaN
# 252327 2015-01-13          4247  BELMOND    50421            NaN     NaN
# 253761 2015-08-11          4247  BELMOND    50421            NaN     NaN
# 255537 2015-08-04          4247  BELMOND    50421            NaN     NaN
# 258387 2015-05-19          4247  BELMOND    50421            NaN     NaN
# 262521 2015-10-13          4247  BELMOND    50421            NaN     NaN
# 263934 2015-10-13          4247  BELMOND    50421            NaN     NaN
# 266383 2015-09-08          4247  BELMOND    50421            NaN     NaN
# 268504 2016-02-23          4247  BELMOND    50421            NaN     NaN
# 270031 2015-05-12          4247  BELMOND    50421            NaN     NaN
#
#          Category                     Category Name  Vendor Number  \
# 964     1012100.0                 CANADIAN WHISKIES             55
# 2871    1062300.0                      FLAVORED RUM             65
# 4448    1031080.0                    VODKA 80 PROOF            380
# 7834    1071100.0                AMERICAN COCKTAILS            395
# 9790    1012200.0                   SCOTCH WHISKIES            260
# 12422   1081200.0                    CREAM LIQUEURS            260
# 13112   1012200.0                   SCOTCH WHISKIES            260
# 13686   1031080.0                    VODKA 80 PROOF            434
# 14529   1012100.0                 CANADIAN WHISKIES            260
# 16512   1012100.0                 CANADIAN WHISKIES             55
# 19443   1032200.0             IMPORTED VODKA - MISC            370
# 23084   1012100.0                 CANADIAN WHISKIES            115
# 23110   1081350.0                SPEARMINT SCHNAPPS            434
# 24082   1012200.0                   SCOTCH WHISKIES             35
# 26604   1062310.0                        SPICED RUM            260
# 27256   1071100.0                AMERICAN COCKTAILS            395
# 27547   1022100.0                           TEQUILA            395
# 27758   1062300.0                      FLAVORED RUM            370
# 29819   1062200.0  PUERTO RICO & VIRGIN ISLANDS RUM            434
# 30141   1071100.0                AMERICAN COCKTAILS             55
# 31851   1062300.0                      FLAVORED RUM             35
# 31930   1081200.0                    CREAM LIQUEURS            260
# 32099   1042100.0                 IMPORTED DRY GINS            260
# 32540   1062300.0                      FLAVORED RUM            370
# 34547   1031200.0                    VODKA FLAVORED            260
# 36506   1081600.0                   WHISKEY LIQUEUR            421
# 37416   1042100.0                 IMPORTED DRY GINS            260
# 39498   1032080.0                    IMPORTED VODKA             65
# 39499   1062300.0                      FLAVORED RUM             65
# 41806   1062310.0                        SPICED RUM            260
# ...           ...                               ...            ...
# 218031  1062300.0                      FLAVORED RUM             65
# 220009  1012100.0                 CANADIAN WHISKIES             65
# 220722  1012100.0                 CANADIAN WHISKIES             55
# 221210  1031200.0                    VODKA FLAVORED            260
# 221749  1062200.0  PUERTO RICO & VIRGIN ISLANDS RUM             35
# 225517  1022100.0                           TEQUILA            421
# 226288  1012200.0                   SCOTCH WHISKIES             35
# 227326  1011200.0         STRAIGHT BOURBON WHISKIES             65
# 228545  1032200.0             IMPORTED VODKA - MISC            370
# 230169  1062200.0  PUERTO RICO & VIRGIN ISLANDS RUM            434
# 231428  1031200.0                    VODKA FLAVORED            260
# 232148  1012100.0                 CANADIAN WHISKIES            115
# 233261  1071100.0                AMERICAN COCKTAILS            395
# 234443  1031080.0                    VODKA 80 PROOF            297
# 235688  1012100.0                 CANADIAN WHISKIES            260
# 237344  1071100.0                AMERICAN COCKTAILS             55
# 239262  1071100.0                AMERICAN COCKTAILS             55
# 239729  1012100.0                 CANADIAN WHISKIES            115
# 239926  1031100.0                   100 PROOF VODKA            297
# 243489  1031080.0                    VODKA 80 PROOF            260
# 251269  1022100.0                           TEQUILA            421
# 252327  1032080.0                    IMPORTED VODKA            370
# 253761  1032200.0             IMPORTED VODKA - MISC            370
# 255537  1012200.0                   SCOTCH WHISKIES             35
# 258387  1031080.0                    VODKA 80 PROOF            297
# 262521  1042100.0                 IMPORTED DRY GINS            260
# 263934  1081330.0                    PEACH SCHNAPPS             65
# 266383  1031080.0                    VODKA 80 PROOF            297
# 268504  1062310.0                        SPICED RUM            260
# 270031  1081390.0                 IMPORTED SCHNAPPS            421
#
#         Item Number                       Item Description  \
# 964           12408                    Canadian Ltd Whisky
# 2871          44428              Cruzan Blueberry Lemonade
# 4448          37338                           UV Vodka PET
# 7834          58838   Jose Cuervo Authentic Lime Margarita
# 9790          10008                   Scoresby Rare Scotch
# 12422         68036          Bailey's Original Irish Cream
# 13112         10008                   Scoresby Rare Scotch
# 13686         36308                          Hawkeye Vodka
# 14529         11298            Crown Royal Canadian Whisky
# 16512         12406                    Canadian Ltd Whisky
# 19443         34026                         Absolut Peppar
# 23084         11788                           Black Velvet
# 23110         82187               Arrow Spearmint Schnapps
# 24082          4866              Dewars White Label Scotch
# 26604         43338              Captain Morgan Spiced Rum
# 27256         58875           Jose Cuervo Golden Margarita
# 27547         89197  Jose Cuervo Especial Reposado Tequila
# 27758         42716                     Malibu Coconut Rum
# 29819         45278                    Paramount White Rum
# 30141         57144                Chi-Chi's White Russian
# 31851         43138                          Bacardi Limon
# 31930         68036          Bailey's Original Irish Cream
# 32099         28868                          Tanqueray Gin
# 32540         42703                   Malibu Pineapple Rum
# 34547         77648                        Smirnoff Citrus
# 36506         64868              Fireball Cinnamon Whiskey
# 37416         28866                          Tanqueray Gin
# 39498         34578                         Pinnacle Vodka
# 39499         44419                Cruzan Black Cherry Rum
# 41806         43338              Captain Morgan Spiced Rum
# ...             ...                                    ...
# 218031        44456                   Cruzan Raspberry Rum
# 220009        10628                   Canadian Club Whisky
# 220722        12408                    Canadian Ltd Whisky
# 221210        77688                          Smirnoff Lime
# 221749        43128                   Bacardi Superior Rum
# 225517        88766                 Tortilla White Tequila
# 226288         4866              Dewars White Label Scotch
# 227326        20248                               Old Crow
# 228545        34190                     Absolut Cherrykran
# 230169        45246                     Paramount Gold Rum
# 231428        77648                        Smirnoff Citrus
# 232148        10550           Black Velvet Toasted Caramel
# 233261        58838   Jose Cuervo Authentic Lime Margarita
# 234443        35916                     Five O'clock Vodka
# 235688        10807                Crown Royal Regal Apple
# 237344        57148          Chi-Chi's Margarita W/tequila
# 239262        57148          Chi-Chi's Margarita W/tequila
# 239729        11776                           Black Velvet
# 239926        35916                     Five O'clock Vodka
# 243489        37996                  Smirnoff Vodka 80 Prf
# 251269        88768                 Tortilla White Tequila
# 252327        34007           Absolut Swedish Vodka 80 Prf
# 253761        34116                        Absolut Mandrin
# 255537         4866              Dewars White Label Scotch
# 258387        35918                     Five O'clock Vodka
# 262521        28868                          Tanqueray Gin
# 263934        82846   Dekuyper Luscious Peachtree Schnapps
# 266383        35916                     Five O'clock Vodka
# 268504        43418                  Captain Morgan Tattoo
# 270031        69667             Dr. Mcgillicuddy's Vanilla
#
#         Bottle Volume (ml)  State Bottle Cost  State Bottle Retail  \
# 964                   1750               9.14                13.71
# 2871                   750               6.83                10.25
# 4448                  1750              10.49                15.99
# 7834                  1750               8.20                12.30
# 9790                  1750              10.50                15.75
# 12422                  750              13.25                19.88
# 13112                 1750              10.50                15.75
# 13686                 1750               7.17                10.76
# 14529                 1750              31.99                47.99
# 16512                  750               3.84                 6.01
# 19443                  750              11.49                17.24
# 23084                 1750               9.70                14.93
# 23110                 1000               5.00                 7.50
# 24082                  750              13.73                20.60
# 26604                 1750              18.00                27.00
# 27256                 1750              10.50                15.75
# 27547                 1000              12.50                18.75
# 27758                  750               7.49                11.24
# 29819                 1750               7.84                11.76
# 30141                 1750               6.50                 9.75
# 31851                 1750              15.00                22.50
# 31930                  750              13.25                19.88
# 32099                 1750              24.99                37.49
# 32540                  750               7.49                11.24
# 34547                 1000               9.25                13.88
# 36506                 1750              15.33                23.00
# 37416                  750              12.25                18.38
# 39498                 1750              12.59                18.89
# 39499                  750               6.83                10.25
# 41806                 1750              18.00                27.00
# ...                    ...                ...                  ...
# 218031                 750               6.83                10.25
# 220009                1750              15.75                23.63
# 220722                1750               7.94                12.51
# 221210                 750               8.25                12.38
# 221749                1750              15.00                22.50
# 225517                 750               6.20                 9.30
# 226288                 750              13.73                20.60
# 227326                1750              10.49                15.74
# 228545                 750              11.49                17.24
# 230169                 750               4.34                 6.51
# 231428                1000               9.25                13.88
# 232148                 750               6.75                10.13
# 233261                1750               8.20                12.30
# 234443                 750               3.37                 5.06
# 235688                 750              15.00                22.50
# 237344                1750               6.50                 9.75
# 239262                1750               6.00                 9.25
# 239729                 750               5.23                 7.85
# 239926                 750               3.37                 5.06
# 243489                 750               8.25                12.38
# 251269                1750              12.64                18.96
# 252327                1000              14.99                22.49
# 253761                 750              11.49                17.24
# 255537                 750              13.73                20.60
# 258387                1750               7.20                10.80
# 262521                1750              24.99                37.49
# 263934                 750               6.30                 9.45
# 266383                 750               3.37                 5.06
# 268504                 750               9.00                13.50
# 270031                1000              11.00                16.50
#
#         Bottles Sold  Sale (Dollars)  Volume Sold (Liters)
# 964                6           82.26                 10.50
# 2871               1           10.25                  0.75
# 4448               6           95.94                 10.50
# 7834               6           73.80                 10.50
# 9790               1           15.75                  1.75
# 12422              3           59.64                  2.25
# 13112              2           31.50                  3.50
# 13686             12          129.12                 21.00
# 14529              6          287.94                 10.50
# 16512             12           72.12                  9.00
# 19443              1           17.24                  0.75
# 23084             18          268.74                 31.50
# 23110              2           15.00                  2.00
# 24082              2           41.20                  1.50
# 26604             12          324.00                 21.00
# 27256              6           94.50                 10.50
# 27547              1           18.75                  1.00
# 27758             12          134.88                  9.00
# 29819              6           70.56                 10.50
# 30141              6           58.50                 10.50
# 31851              2           45.00                  3.50
# 31930              2           39.76                  1.50
# 32099              6          224.94                 10.50
# 32540              3           33.72                  2.25
# 34547              3           41.64                  3.00
# 36506              1           23.00                  1.75
# 37416             12          220.56                  9.00
# 39498              6          113.34                 10.50
# 39499              1           10.25                  0.75
# 41806              6          162.00                 10.50
# ...              ...             ...                   ...
# 218031             2           20.50                  1.50
# 220009             6          141.78                 10.50
# 220722            12          150.12                 21.00
# 221210             2           24.76                  1.50
# 221749             6          135.00                 10.50
# 225517             3           27.90                  2.25
# 226288             1           20.60                  0.75
# 227326             1           15.74                  1.75
# 228545             1           17.24                  0.75
# 230169            24          156.24                 18.00
# 231428             1           13.88                  1.00
# 232148            12          121.56                  9.00
# 233261             6           73.80                 10.50
# 234443            12           60.72                  9.00
# 235688             2           45.00                  1.50
# 237344             6           58.50                 10.50
# 239262             2           18.50                  3.50
# 239729            12           94.20                  9.00
# 239926            12           60.72                  9.00
# 243489            12          148.56                  9.00
# 251269             1           18.96                  1.75
# 252327             1           22.49                  1.00
# 253761             1           17.24                  0.75
# 255537             1           20.60                  0.75
# 258387             6           64.80                 10.50
# 262521             6          224.94                 10.50
# 263934             2           18.90                  1.50
# 266383            12           60.72                  9.00
# 268504             2           27.00                  1.50
# 270031             1           16.50                  1.00
#
# [178 rows x 17 columns]

# %%
df_store_county_ref = pd.DataFrame(data=df['Store Number'].unique())
df_store_county_ref.columns = ['Store Number']

# %%
df_temp = pd.merge(df_store_county_ref,df[['Store Number', 'County Number']],how='inner', on='Store Number')

# %%
df_temp
# Out:
#         Store Number  County Number
# 0               3717            9.0
# 1               3717            9.0
# 2               3717            9.0
# 3               3717            9.0
# 4               3717            9.0
# 5               3717            9.0
# 6               3717            9.0
# 7               3717            9.0
# 8               3717            9.0
# 9               3717            9.0
# 10              3717            9.0
# 11              3717            9.0
# 12              3717            9.0
# 13              3717            9.0
# 14              3717            9.0
# 15              3717            9.0
# 16              3717            9.0
# 17              3717            9.0
# 18              3717            9.0
# 19              3717            9.0
# 20              3717            9.0
# 21              3717            9.0
# 22              3717            9.0
# 23              3717            9.0
# 24              3717            9.0
# 25              3717            9.0
# 26              3717            9.0
# 27              3717            9.0
# 28              3717            9.0
# 29              3717            9.0
# ...              ...            ...
# 270925          4985           75.0
# 270926          4985           75.0
# 270927          4737           11.0
# 270928          4737           11.0
# 270929          4737           11.0
# 270930          4737           11.0
# 270931          4776           14.0
# 270932          4776           14.0
# 270933          4338           64.0
# 270934          4338           64.0
# 270935          4338           64.0
# 270936          4338           64.0
# 270937          4338           64.0
# 270938          4338           64.0
# 270939          9023           14.0
# 270940          9018           31.0
# 270941          5216            NaN
# 270942          5216            NaN
# 270943          5216            NaN
# 270944          5237            NaN
# 270945          5237            NaN
# 270946          5237            NaN
# 270947          5237            NaN
# 270948          5237            NaN
# 270949          5237            NaN
# 270950          5201           31.0
# 270951          5201           31.0
# 270952          5201           31.0
# 270953          4778           11.0
# 270954          4778           11.0
#
# [270955 rows x 2 columns]

# %%
df.ix[df['County Number'].isnull(), 'County Number'] =

# %%
df[df['Store Number']==5210]
# Out:
#              Date  Store Number      City Zip Code  County Number County  \
# 2549   2016-03-22          5210  CLARINDA    51632            NaN    NaN
# 2678   2016-03-29          5210  CLARINDA    51632            NaN    NaN
# 15946  2016-02-23          5210  CLARINDA    51632            NaN    NaN
# 18468  2016-03-15          5210  CLARINDA    51632            NaN    NaN
# 24024  2016-03-22          5210  CLARINDA    51632            NaN    NaN
# 26752  2016-02-23          5210  CLARINDA    51632            NaN    NaN
# 27605  2016-01-05          5210  CLARINDA    51632            NaN    NaN
# 30119  2016-02-16          5210  CLARINDA    51632            NaN    NaN
# 35051  2016-03-29          5210  CLARINDA    51632            NaN    NaN
# 35250  2016-03-29          5210  CLARINDA    51632            NaN    NaN
# 37039  2016-02-02          5210  CLARINDA    51632            NaN    NaN
# 38373  2016-03-29          5210  CLARINDA    51632            NaN    NaN
# 39218  2016-03-22          5210  CLARINDA    51632            NaN    NaN
# 42789  2016-02-02          5210  CLARINDA    51632            NaN    NaN
# 45313  2016-03-08          5210  CLARINDA    51632            NaN    NaN
# 45611  2016-02-16          5210  CLARINDA    51632            NaN    NaN
# 47393  2016-02-02          5210  CLARINDA    51632            NaN    NaN
# 54397  2016-02-16          5210  CLARINDA    51632            NaN    NaN
# 54476  2016-02-02          5210  CLARINDA    51632            NaN    NaN
# 58905  2016-02-23          5210  CLARINDA    51632            NaN    NaN
# 59648  2016-02-16          5210  CLARINDA    51632            NaN    NaN
# 63534  2016-03-01          5210  CLARINDA    51632            NaN    NaN
# 64102  2016-03-08          5210  CLARINDA    51632            NaN    NaN
# 73790  2016-02-09          5210  CLARINDA    51632            NaN    NaN
# 74768  2016-03-15          5210  CLARINDA    51632            NaN    NaN
# 87853  2016-01-26          5210  CLARINDA    51632            NaN    NaN
# 89373  2016-02-16          5210  CLARINDA    51632            NaN    NaN
# 89506  2016-03-15          5210  CLARINDA    51632            NaN    NaN
# 90142  2016-02-02          5210  CLARINDA    51632            NaN    NaN
# 92773  2016-03-01          5210  CLARINDA    51632            NaN    NaN
# ...           ...           ...       ...      ...            ...    ...
# 170303 2016-02-23          5210  CLARINDA    51632            NaN    NaN
# 170484 2016-01-05          5210  CLARINDA    51632            NaN    NaN
# 170524 2016-01-19          5210  CLARINDA    51632            NaN    NaN
# 172881 2016-01-05          5210  CLARINDA    51632            NaN    NaN
# 173820 2016-02-16          5210  CLARINDA    51632            NaN    NaN
# 176063 2016-02-23          5210  CLARINDA    51632            NaN    NaN
# 176446 2016-02-16          5210  CLARINDA    51632            NaN    NaN
# 177824 2016-01-12          5210  CLARINDA    51632            NaN    NaN
# 182336 2016-02-02          5210  CLARINDA    51632            NaN    NaN
# 184387 2016-03-08          5210  CLARINDA    51632            NaN    NaN
# 185540 2016-02-16          5210  CLARINDA    51632            NaN    NaN
# 194241 2016-01-05          5210  CLARINDA    51632            NaN    NaN
# 199501 2016-03-22          5210  CLARINDA    51632            NaN    NaN
# 206577 2016-01-05          5210  CLARINDA    51632            NaN    NaN
# 210270 2016-03-29          5210  CLARINDA    51632            NaN    NaN
# 211792 2016-01-05          5210  CLARINDA    51632            NaN    NaN
# 213532 2016-03-22          5210  CLARINDA    51632            NaN    NaN
# 218033 2016-03-15          5210  CLARINDA    51632            NaN    NaN
# 224610 2016-01-26          5210  CLARINDA    51632            NaN    NaN
# 230854 2016-02-23          5210  CLARINDA    51632            NaN    NaN
# 230942 2016-02-16          5210  CLARINDA    51632            NaN    NaN
# 233303 2016-01-12          5210  CLARINDA    51632            NaN    NaN
# 241865 2016-02-09          5210  CLARINDA    51632            NaN    NaN
# 244525 2016-03-08          5210  CLARINDA    51632            NaN    NaN
# 245114 2016-03-15          5210  CLARINDA    51632            NaN    NaN
# 254994 2016-03-08          5210  CLARINDA    51632            NaN    NaN
# 256883 2016-01-19          5210  CLARINDA    51632            NaN    NaN
# 257642 2016-02-16          5210  CLARINDA    51632            NaN    NaN
# 263730 2016-01-05          5210  CLARINDA    51632            NaN    NaN
# 269482 2016-03-01          5210  CLARINDA    51632            NaN    NaN
#
#          Category                       Category Name  Vendor Number  \
# 2549    1022100.0                             TEQUILA             35
# 2678    1012100.0                   CANADIAN WHISKIES             65
# 15946   1011100.0                    BLENDED WHISKIES             65
# 18468   1031200.0                      VODKA FLAVORED            380
# 24024   1062300.0                        FLAVORED RUM             65
# 26752   1031080.0                      VODKA 80 PROOF            260
# 27605   1062300.0                        FLAVORED RUM            370
# 30119   1011100.0                    BLENDED WHISKIES             65
# 35051   1041100.0                   AMERICAN DRY GINS            434
# 35250   1012300.0                      IRISH WHISKIES            370
# 37039   1081200.0                      CREAM LIQUEURS            260
# 38373   1062310.0                          SPICED RUM            259
# 39218   1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS            192
# 42789   1011200.0           STRAIGHT BOURBON WHISKIES             65
# 45313   1011300.0                  TENNESSEE WHISKIES             85
# 45611   1081330.0                      PEACH SCHNAPPS             65
# 47393   1012100.0                   CANADIAN WHISKIES             65
# 54397   1081030.0                     COFFEE LIQUEURS            370
# 54476   1031080.0                      VODKA 80 PROOF             55
# 58905   1012100.0                   CANADIAN WHISKIES            260
# 59648   1012100.0                   CANADIAN WHISKIES            260
# 63534   1081390.0                   IMPORTED SCHNAPPS            421
# 64102   1051110.0                 BLACKBERRY BRANDIES            434
# 73790   1022100.0                             TEQUILA            395
# 74768   1012100.0                   CANADIAN WHISKIES            260
# 87853   1032200.0               IMPORTED VODKA - MISC            370
# 89373   1071100.0                  AMERICAN COCKTAILS            434
# 89506   1012300.0                      IRISH WHISKIES            370
# 90142   1012100.0                   CANADIAN WHISKIES            260
# 92773   1031200.0                      VODKA FLAVORED            380
# ...           ...                                 ...            ...
# 170303  1062310.0                          SPICED RUM            260
# 170484  1062310.0                          SPICED RUM             35
# 170524  1012100.0                   CANADIAN WHISKIES            115
# 172881  1081600.0                     WHISKEY LIQUEUR            260
# 173820  1012100.0                   CANADIAN WHISKIES            260
# 176063  1011200.0           STRAIGHT BOURBON WHISKIES             65
# 176446  1082100.0                                 NaN            130
# 177824  1012100.0                   CANADIAN WHISKIES            260
# 182336  1012100.0                   CANADIAN WHISKIES             85
# 184387  1031080.0                      VODKA 80 PROOF            421
# 185540  1081300.0                 PEPPERMINT SCHNAPPS            322
# 194241  1011100.0                    BLENDED WHISKIES            297
# 199501  1012200.0                     SCOTCH WHISKIES             55
# 206577  1081600.0                     WHISKEY LIQUEUR            421
# 210270  1081390.0                   IMPORTED SCHNAPPS            260
# 211792  1022100.0                             TEQUILA            410
# 213532  1081010.0                   AMERICAN AMARETTO             55
# 218033  1031080.0                      VODKA 80 PROOF            260
# 224610  1081230.0                WHITE CREME DE CACAO            434
# 230854  1011100.0                    BLENDED WHISKIES            260
# 230942  1011200.0           STRAIGHT BOURBON WHISKIES            421
# 233303  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS            192
# 241865  1081300.0                 PEPPERMINT SCHNAPPS            322
# 244525  1062310.0                          SPICED RUM            259
# 245114  1081300.0                 PEPPERMINT SCHNAPPS            434
# 254994  1031080.0                      VODKA 80 PROOF             55
# 256883  1031080.0                      VODKA 80 PROOF            260
# 257642  1031080.0                      VODKA 80 PROOF            300
# 263730  1011100.0                    BLENDED WHISKIES            300
# 269482  1012210.0                  SINGLE MALT SCOTCH            260
#
#         Item Number                      Item Description  Bottle Volume (ml)  \
# 2549          89099                       Cazadores Anejo                 750
# 2678          10627                  Canadian Club Whisky                1000
# 15946         24456                 Kessler Blend Whiskey                 750
# 18468         41693             Uv Blue (raspberry) Vodka                 750
# 24024         44456                  Cruzan Raspberry Rum                 750
# 26752         37997                 Smirnoff Vodka 80 Prf                1000
# 27605         42716                    Malibu Coconut Rum                 750
# 30119         24458                 Kessler Blend Whiskey                1750
# 35051         31657                         Paramount Gin                1000
# 35250         15626                               Jameson                 750
# 37039         74086                        Godiva Liqueur                 750
# 38373         43028             Admiral Nelson Spiced Rum                1750
# 39218         65257                  Jagermeister Liqueur                1000
# 42789         27410                        Jim Beam Honey                 750
# 45313         26824  Jack Daniels Old #7 Black Lbl Square                 375
# 45611         82847                    Dekuyper Peachtree                1000
# 47393         10626                  Canadian Club Whisky                 750
# 54397         67527                 Kahlua Coffee Liqueur                1000
# 54476         35314                          Barton Vodka                 375
# 58905         10807               Crown Royal Regal Apple                 750
# 59648         10834                     Crown Royal Black                 375
# 63534         69657        Dr. Mcgillicuddy's Mentholmint                1000
# 64102         55084           Paramount Blackberry Brandy                 375
# 73790         87408           Jose Cuervo Especial Silver                 750
# 74768         11296                           Crown Royal                 750
# 87853         34116                       Absolut Mandrin                 750
# 89373         63530     Salvador's Original Margarita PET                1750
# 89506         15628                               Jameson                1750
# 90142         10808               Crown Royal Regal Apple                1000
# 92773         40632                            UV Whipped                 750
# ...             ...                                   ...                 ...
# 170303        43337             Captain Morgan Spiced Rum                1000
# 170484        43205                      Bacardi Oakheart                 750
# 170524        11774                          Black Velvet                 375
# 172881        67264           Yukon Jack Canadian Liqueur                 375
# 173820        10803          Crown Royal Regal Apple Mini                 300
# 176063        20247                              Old Crow                1000
# 176446        64136                    Disaronno Amaretto                 750
# 177824        10805               Crown Royal Regal Apple                 375
# 182336        12467                  Canadian Mist Whisky                1000
# 184387        36978                         Nikolai Vodka                1750
# 185540        75214                            Kinky Blue                 750
# 194241        23828                             Five Star                1750
# 199501         8827                              Lauder's                1000
# 206577        64865         Fireball Cinnamon Whiskey PET                 750
# 210270        65066        Goldschlager Cinnamon Schnapps                 750
# 211792        88296                 Patron Tequila Silver                 750
# 213532        73986                     Di Amore Amaretto                 750
# 218033        37417                    Popov Vodka 80 Prf                1000
# 224610        78866        Paramount Creme De Cacao/white                 750
# 230854        25608           Seagrams 7 Crown Bl Whiskey                1750
# 230942        16517                   Ancient Age Bourbon                1000
# 233303        65257                  Jagermeister Liqueur                1000
# 241865        75214                            Kinky Blue                 750
# 244525        43984      Admiral Nelson Cherry Spiced Rum                 750
# 245114        81206         Paramount Peppermint Schnapps                 750
# 254994        35318                          Barton Vodka                1750
# 256883        37426           Popov Vodka 80 Prf Traveler                 750
# 257642        36908                   Mccormick Vodka Pet                1750
# 263730        24728          Mccormick Blend Whiskey, Pet                1750
# 269482         5696               Oban Single Malt Scotch                 750
#
#         State Bottle Cost  State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 2549                23.33                35.00             1           35.00
# 2678                 9.71                14.57            12          174.84
# 15946                5.51                 8.27            12           99.24
# 18468                6.50                 9.75            12          117.00
# 24024                6.83                10.25             2           20.50
# 26752                9.25                13.88            12          166.56
# 27605                7.49                11.24            12          134.88
# 30119               11.02                16.53             6           99.18
# 35051                4.30                 6.45            12           77.40
# 35250               14.99                22.49             3           67.47
# 37039               17.00                25.50             1           25.50
# 38373               11.55                17.33             6          103.98
# 39218               15.54                23.31            12          279.72
# 42789               10.49                15.74             3           47.22
# 45313                6.77                10.16             6           60.96
# 45611                7.87                11.81            12          141.72
# 47393                7.88                11.82            12          141.84
# 54397               15.49                23.24             3           69.72
# 54476                1.71                 2.57            24           61.68
# 58905               15.00                22.50            12          270.00
# 59648                8.25                12.38             2           24.76
# 63534               11.00                16.50             2           33.00
# 64102                3.55                 5.33             6           31.98
# 73790               10.49                15.74            12          188.88
# 74768               15.00                22.50            12          270.00
# 87853               11.49                17.24             2           34.48
# 89373                6.00                 9.00             6           54.00
# 89506               29.98                44.97             6          269.82
# 90142               18.50                27.75            12          333.00
# 92773                6.50                 9.75             2           19.50
# ...                   ...                  ...           ...             ...
# 170303              11.75                17.63            12          211.56
# 170484               7.50                11.25             1           11.25
# 170524               3.07                 4.61            24          110.64
# 172881               5.25                 7.88             6           47.28
# 173820               7.35                11.03             1           11.03
# 176063               5.77                 8.66            12          103.92
# 176446              13.86                20.79             2           41.58
# 177824               7.75                11.63             4           46.52
# 182336               7.22                10.83             4           43.32
# 184387               6.92                10.38             6           62.28
# 185540              10.00                15.00             2           30.00
# 194241               7.46                11.19             6           67.14
# 199501               6.14                 9.21             3           27.63
# 206577               8.98                13.47            12          161.64
# 210270              13.00                19.50             2           39.00
# 211792              27.00                40.50             2           81.00
# 213532               6.00                 9.00             3           27.00
# 218033               5.50                 8.25            12           99.00
# 224610               4.75                 7.13             3           21.39
# 230854              11.96                17.94             6          107.64
# 230942               7.50                11.25            12          135.00
# 233303              15.54                23.31             3           69.93
# 241865              10.00                15.00             2           30.00
# 244525               5.78                 8.67             2           17.34
# 245114               3.75                 5.63             3           16.89
# 254994               6.92                10.38             6           62.28
# 256883               4.50                 6.75            12           81.00
# 257642               7.47                11.21             6           67.26
# 263730               7.67                11.51             6           69.06
# 269482              40.50                60.75             1           60.75
#
#         Volume Sold (Liters)
# 2549                    0.75
# 2678                   12.00
# 15946                   9.00
# 18468                   9.00
# 24024                   1.50
# 26752                  12.00
# 27605                   9.00
# 30119                  10.50
# 35051                  12.00
# 35250                   2.25
# 37039                   0.75
# 38373                  10.50
# 39218                  12.00
# 42789                   2.25
# 45313                   2.25
# 45611                  12.00
# 47393                   9.00
# 54397                   3.00
# 54476                   9.00
# 58905                   9.00
# 59648                   0.75
# 63534                   2.00
# 64102                   2.25
# 73790                   9.00
# 74768                   9.00
# 87853                   1.50
# 89373                  10.50
# 89506                  10.50
# 90142                  12.00
# 92773                   1.50
# ...                      ...
# 170303                 12.00
# 170484                  0.75
# 170524                  9.00
# 172881                  2.25
# 173820                  0.30
# 176063                 12.00
# 176446                  1.50
# 177824                  1.50
# 182336                  4.00
# 184387                 10.50
# 185540                  1.50
# 194241                 10.50
# 199501                  3.00
# 206577                  9.00
# 210270                  1.50
# 211792                  1.50
# 213532                  2.25
# 218033                 12.00
# 224610                  2.25
# 230854                 10.50
# 230942                 12.00
# 233303                  3.00
# 241865                  1.50
# 244525                  1.50
# 245114                  2.25
# 254994                 10.50
# 256883                  9.00
# 257642                 10.50
# 263730                 10.50
# 269482                  0.75
#
# [80 rows x 17 columns]

# %%
df['County Number'].value_counts()
# Out:
# 77.0    49102
# 57.0    23511
# 82.0    16678
# 7.0     15083
# 52.0    13189
# 78.0     9111
# 85.0     8959
# 97.0     8562
# 31.0     7757
# 17.0     6374
# 29.0     4090
# 70.0     3983
# 23.0     3576
# 90.0     3529
# 30.0     3413
# 56.0     3324
# 94.0     3154
# 64.0     2996
# 50.0     2834
# 11.0     2748
# 25.0     2708
# 63.0     2603
# 91.0     2465
# 9.0      2243
# 8.0      2110
# 79.0     2089
# 21.0     1917
# 14.0     1915
# 53.0     1874
# 71.0     1720
#         ...
# 37.0      677
# 99.0      672
# 83.0      663
# 47.0      634
# 45.0      607
# 46.0      588
# 1.0       585
# 38.0      566
# 76.0      525
# 65.0      508
# 58.0      484
# 59.0      476
# 19.0      464
# 39.0      438
# 13.0      424
# 12.0      402
# 98.0      388
# 41.0      363
# 68.0      353
# 72.0      352
# 54.0      344
# 87.0      298
# 89.0      245
# 2.0       234
# 5.0       227
# 27.0      224
# 26.0      203
# 80.0      202
# 93.0      160
# 36.0       27
# Name: County Number, dtype: int64

# %%
# Convert dates

# %%
# Drop or replace bad values

# Convert integers

# %% [markdown]
# ## Filter the Data
#
# Some stores may have opened or closed in 2015. These data points will heavily skew our models, so we need to filter them out or find a way to deal with them.
#
# You'll need to provide a summary in your project report about these data points. You may also consider using the monthly sales in your model and including other information (number of months or days each store is open) in your data to handle these unusual cases.
#
# Let's record the first and last sales dates for each store. We'll save this information for later when we fit our models.

# %%
# Determine which stores were open all of 2015
# Find the first and last sales date.



# Filter out stores that opened or closed throughout the year
# You may want to save this step until you start modelling

# %%
df['Date'].describe()
# Out:
# count                  270955
# unique                    274
# top       2015-12-01 00:00:00
# freq                     1555
# first     2015-01-05 00:00:00
# last      2016-03-31 00:00:00
# Name: Date, dtype: object

# %%
df['Date'].min()
# Out:
# Timestamp('2015-01-05 00:00:00')

# %%
store_min = df.groupby('Store Number')[['Date']].min()
store_max = df.groupby('Store Number')[['Date']].max()

# %%
store_date = pd.merge(df.groupby('Store Number')[['Date']].min(),df.groupby('Store Number')[['Date']].max(), how='outer', left_index=True, right_index=True)

# %%
store_date.columns = ['first_date', 'last_date']

# %%
start_time = pd.Timestamp('20150101')
end_time = pd.Timestamp('20151231')

# %%
store_date[(store_date['first_date']>=start_time) & (store_date['first_date']<=end_time) & (store_date['last_date']>=start_time) & (store_date['last_date']<=end_time)]
# Out:
#              first_date  last_date
# Store Number
# 2205         2015-01-06 2015-12-28
# 2367         2015-01-06 2015-06-09
# 2487         2015-01-05 2015-11-02
# 2599         2015-01-05 2015-01-14
# 2951         2015-01-08 2015-01-29
# 2953         2015-01-08 2015-03-26
# 2954         2015-01-08 2015-03-26
# 2955         2015-01-08 2015-03-26
# 2956         2015-01-08 2015-03-25
# 2958         2015-01-05 2015-02-05
# 2959         2015-01-05 2015-03-25
# 2961         2015-01-08 2015-01-29
# 2962         2015-01-05 2015-03-26
# 2963         2015-01-05 2015-03-19
# 3437         2015-01-08 2015-12-30
# 3440         2015-01-08 2015-04-08
# 3451         2015-01-08 2015-02-26
# 3529         2015-01-06 2015-04-14
# 3631         2015-01-05 2015-08-24
# 3692         2015-01-08 2015-01-29
# 3761         2015-01-06 2015-03-24
# 3864         2015-01-13 2015-09-02
# 3925         2015-01-07 2015-02-25
# 3969         2015-01-06 2015-03-12
# 3970         2015-01-07 2015-12-29
# 3973         2015-01-13 2015-11-12
# 4012         2015-01-07 2015-04-01
# 4030         2015-01-06 2015-03-17
# 4059         2015-01-06 2015-01-13
# 4071         2015-01-08 2015-05-14
# ...                 ...        ...
# 4834         2015-01-05 2015-07-13
# 4855         2015-02-23 2015-11-16
# 4860         2015-02-11 2015-12-02
# 4870         2015-01-05 2015-02-23
# 4881         2015-01-08 2015-11-24
# 4889         2015-01-08 2015-04-09
# 4920         2015-01-06 2015-08-04
# 4939         2015-01-08 2015-01-08
# 4954         2015-02-24 2015-07-28
# 4990         2015-01-06 2015-03-10
# 5008         2015-01-06 2015-03-17
# 5026         2015-01-05 2015-05-11
# 5030         2015-01-08 2015-01-29
# 5032         2015-01-08 2015-07-13
# 5033         2015-01-06 2015-03-24
# 5036         2015-01-06 2015-05-19
# 5038         2015-01-08 2015-07-30
# 5053         2015-09-09 2015-09-09
# 5056         2015-07-06 2015-07-06
# 5084         2015-02-17 2015-06-23
# 5085         2015-01-06 2015-01-06
# 5093         2015-01-22 2015-12-23
# 5136         2015-05-04 2015-06-04
# 5139         2015-05-07 2015-11-05
# 5156         2015-08-06 2015-11-19
# 5161         2015-06-22 2015-10-05
# 5168         2015-07-21 2015-12-08
# 5193         2015-12-22 2015-12-22
# 5201         2015-12-01 2015-12-01
# 9018         2015-10-27 2015-10-27
#
# [91 rows x 2 columns]

# %% [markdown]
# ## Compute New Columns and Tables
#
# Since we're trying to predict sales and/or profits, we'll want to compute some intermediate data. There are a lot of ways to do thisand good use of pandas is crucial. For example, for each transaction we may want to know:
# * margin, retail cost minus bottle cost
# * price per bottle
# * price per liter
#
# We'll need to make a new dataframe that indexes quantities by store:
# * sales per store for all of 2015
# * sales per store for Q1 2015
# * sales per store for Q1 2016
# * total volumes sold
# * mean transaction revenue, gross margin, price per bottle, price per liter, etc.
# * average sales per day
# * number of days open
#
# Make sure to retain other variables that we'll want to use to build our models, such as zip code, county number, city, etc. We recommend that you spend some time thinking about the model you may want to fit and computing enough of the suggested quantities to give you a few options.
#
# Bonus tasks:
# * Restrict your attention to stores that were open for all of 2015 and Q1 2016. Stores that opened or closed in 2015 will introduce outliers into your data.
# * For each transaction we have the item category. You may be able to determine the store type (primarily wine, liquor, all types of alcohol, etc.) by the most common transaction category for each store. This could be a useful categorical variable for modelling.

# %%
# Margin and Price per liter

# %%
# Sales per store, 2015

# Filter by our start and end dates
df.sort_values(by=["Store Number", "Date"], inplace=True)
start_date = pd.Timestamp("20150101")
end_date = pd.Timestamp("20151231")
mask = (df['Date'] >= start_date) & (df['Date'] <= end_date)
sales = df[mask]

# Group by store name
sales = sales.groupby(by=["Store Number"], as_index=False)
# Compute sums, means
sales = sales.agg({"Sale (Dollars)": [np.sum, np.mean],
                   "Volume Sold (Liters)": [np.sum, np.mean],
                   "Margin": np.mean,
                   "Price per Liter": np.mean,
                   "Zip Code": lambda x: x.iloc[0], # just extract once, should be the same
                   "City": lambda x: x.iloc[0],
                   "County Number": lambda x: x.iloc[0]})
# Collapse the column indices
sales.columns = [' '.join(col).strip() for col in sales.columns.values]
# Rename columns

# Quick check
sales.head()

# %%
# Q1 sales, may want to also use aggregate as above to have more columns (means, etc.)

# Sales 2015  Q1

# Sales 2016 Q1

# %% [markdown]
# Proceed with any calculations that you need for your models, such as grouping
# sales by zip code, most common vendor number per store, etc. Once you have finished adding columns, be sure to save the dataframe.

# %%
# Compute more things
# ...

# %%
# Save this dataframe

# Let's add the dates computed above to this data.
sales["First Date"] = dates['Date amin']
sales["Last Date"] = dates['Date amax']

sales.to_csv("sales.csv")
